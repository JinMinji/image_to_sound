# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd ..

# %%
# !git init
# Out:
# Initialized empty Git repository in /.git/

# %%
# !git config --global user.email "alswl_1110@naver.com"
# !git config --global user.name "Minji Jin"

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/   sbin/   tensorflow-1.15.2/  var/
# boot/     etc/   lib64/  proc/  srv/    tmp/
# content/  home/  media/  root/  swift/  tools/
# datalab/  lib/   mnt/    run/   sys/    usr/

# %%
cd ..
# Out:
# /

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/   sbin/   tensorflow-1.15.2/  var/
# boot/     etc/   lib64/  proc/  srv/    tmp/
# content/  home/  media/  root/  swift/  tools/
# datalab/  lib/   mnt/    run/   sys/    usr/
